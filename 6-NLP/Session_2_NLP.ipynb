# %%
import numpy as np
import pandas as pd
import nltk
import spacy
import string

# %%
df = pd.read_csv("/content/twcs.csv")
# Out:
# /tmp/ipykernel_8596/706236439.py:1: DtypeWarning: Columns (1,2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/twcs.csv")

# %%
df
# Out:
#          tweet_id   author_id inbound                      created_at  \
# 0             1.0  sprintcare   False  Tue Oct 31 22:10:47 +0000 2017
# 1             2.0      115712    True  Tue Oct 31 22:11:45 +0000 2017
# 2             3.0      115712    True  Tue Oct 31 22:08:27 +0000 2017
# 3             4.0  sprintcare   False  Tue Oct 31 21:54:49 +0000 2017
# 4             5.0      115712    True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...     ...                             ...
# 1048569       NaN         NaN     NaN                             NaN
# 1048570       NaN         NaN     NaN                             NaN
# 1048571       NaN         NaN     NaN                             NaN
# 1048572       NaN         NaN     NaN                             NaN
# 1048573       NaN         NaN     NaN                             NaN
#
#                                                       text response_tweet_id  \
# ...

# %%
df = df[["text"]]

# %%
df
# Out:
#                                                       text
# 0        @115712 I understand. I would like to assist y...
# 1            @sprintcare and how do you propose we do that
# 2        @sprintcare I have sent several private messag...
# 3        @115712 Please send us a Private Message so th...
# 4                                       @sprintcare I did.
# ...                                                    ...
# 1048569                                                NaN
# 1048570                                                NaN
# 1048571                                                NaN
# 1048572                                                NaN
# 1048573                                                NaN
#
# [1048574 rows x 1 columns]

# %%
df["text"].str.lower()
# Out:
# 0          @115712 i understand. i would like to assist y...
# 1              @sprintcare and how do you propose we do that
# 2          @sprintcare i have sent several private messag...
# 3          @115712 please send us a private message so th...
# 4                                         @sprintcare i did.
#                                  ...
# 1048569                                                  NaN
# 1048570                                                  NaN
# 1048571                                                  NaN
# 1048572                                                  NaN
# 1048573                                                  NaN
# Name: text, Length: 1048574, dtype: object

# %%
punc = string.punctuation

# %%
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_puncituation(text):
  return text.translate(str.maketrans('','',punc))

df.loc[:, 'text'] = df['text'].fillna('') # Fill NaN values with empty strings
df.loc[:, "text_without_punc"] = df['text'].apply(lambda text : remove_puncituation(text))
# Out:
# /tmp/ipykernel_8596/970883590.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].fillna('') # Fill NaN values with empty strings
# /tmp/ipykernel_8596/970883590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_without_punc"]=df['text'].apply(lambda text : remove_puncituation(text))

# %%
df
# Out:
#                                                       text  \
# 0        @115712 I understand. I would like to assist y...
# 1            @sprintcare and how do you propose we do that
# 2        @sprintcare I have sent several private messag...
# 3        @115712 Please send us a Private Message so th...
# 4                                       @sprintcare I did.
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
#                                          text_without_punc
# 0        115712 I understand I would like to assist you...
# 1             sprintcare and how do you propose we do that
# 2        sprintcare I have sent several private message...
# 3        115712 Please send us a Private Message so tha...
# 4                                         sprintcare I did
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
# [1048574 rows x 2 columns]

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words("english"))
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
  return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_without_stopwords"] = df["text_without_punc"].apply(lambda text : remove_stopwords(text))
# Out:
# /tmp/ipykernel_8596/2489503073.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_without_stopwords"] = df["text_without_punc"].apply(lambda text : remove_stopwords(text))

# %%
df
# Out:
#                                                       text  \
# 0        @115712 I understand. I would like to assist y...
# 1            @sprintcare and how do you propose we do that
# 2        @sprintcare I have sent several private messag...
# 3        @115712 Please send us a Private Message so th...
# 4                                       @sprintcare I did.
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
#                                          text_without_punc  \
# 0        115712 I understand I would like to assist you...
# 1             sprintcare and how do you propose we do that
# 2        sprintcare I have sent several private message...
# 3        115712 Please send us a Private Message so tha...
# 4                                         sprintcare I did
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
# ...

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()


def stem_words(text):
  return " ".join([stemmer.stem(word)for word in text.split()])

df["text_stemmed"] = df['text_without_stopwords'].apply(lambda text : stem_words(text))
# Out:
# /tmp/ipykernel_8596/3122185515.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_stemmed"] = df['text_without_stopwords'].apply(lambda text : stem_words(text))

# %%
df
# Out:
#                                                       text  \
# 0        @115712 I understand. I would like to assist y...
# 1            @sprintcare and how do you propose we do that
# 2        @sprintcare I have sent several private messag...
# 3        @115712 Please send us a Private Message so th...
# 4                                       @sprintcare I did.
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
#                                          text_without_punc  \
# 0        115712 I understand I would like to assist you...
# 1             sprintcare and how do you propose we do that
# 2        sprintcare I have sent several private message...
# 3        115712 Please send us a Private Message so tha...
# 4                                         sprintcare I did
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
# ...

# %%
from nltk.stem import WordNetLemmatizer
nltk.download("wordnet")
lemmatizer = WordNetLemmatizer()

def lemmize_words(text):
  return " ".join([lemmatizer.lemmatize(word)for word in str(text).split()])

df["text_lemmatized"] = df["text_without_stopwords"].apply(lambda text : lemmize_words(text))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# /tmp/ipykernel_8596/292666052.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_lemmatized"] = df["text_without_stopwords"].apply(lambda text : lemmize_words(text))

# %%
df
# Out:
#                                                       text  \
# 0        @115712 I understand. I would like to assist y...
# 1            @sprintcare and how do you propose we do that
# 2        @sprintcare I have sent several private messag...
# 3        @115712 Please send us a Private Message so th...
# 4                                       @sprintcare I did.
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
#                                          text_without_punc  \
# 0        115712 I understand I would like to assist you...
# 1             sprintcare and how do you propose we do that
# 2        sprintcare I have sent several private message...
# 3        115712 Please send us a Private Message so tha...
# 4                                         sprintcare I did
# ...                                                    ...
# 1048569
# 1048570
# 1048571
# 1048572
# 1048573
#
# ...
